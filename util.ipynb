# %%
import pandas as pd
df = pd.read_parquet('/home/fkkarami/workspace/amazon/job-posting-structure/auxiliary_files/amazon-jobs-data/20250121-140509-0244d/final_merged_data.parquet')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26027 entries, 0 to 26026
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   job_guid                        26027 non-null  object
#  1   job_icims_id                    23278 non-null  object
#  2   metadata_event_utc_timestamp    26027 non-null  datetime64[ns]
#  3   metadata_publish_utc_timestamp  26027 non-null  datetime64[ns]
#  4   basic_qualifications            26027 non-null  object
#  5   preferred_qualifications        26027 non-null  object
#  6   external_qualifications         26027 non-null  object
#  7   country                         26027 non-null  object
#  8   location_country_name           26027 non-null  object
#  9   city                            26027 non-null  object
#  10  state                           26027 non-null  object
#  11  job_classification_title        26027 non-null  object
# ...
